# %% [markdown]
# # Questão 12
#
# Repita o Exercício 4 utilizando a regra do ponto médio e os resultados do Exercício 10.

# %%
import numpy as np
import sympy as sp

def ponto_medio(f, a, b):

    xm = (a+b)/2

    return (b-a)*f(xm)

x = sp.symbols('x')

# a)

f_expr = sp.cos(x)**2

f = sp.lambdify(x, f_expr, 'numpy')

a = -0.25
b = 0.25

I_pm = ponto_medio(f, a, b)

I_exato = float(sp.integrate(f_expr, (x,a,b)))

f2 = sp.diff(f_expr, x, 2)

M2 = max(abs(float(f2.subs(x,a))),
         abs(float(f2.subs(x,b))))

erro_limite = ((b-a)**3/24)*M2

erro_real = abs(I_exato - I_pm)

print("a)")
print("Ponto Médio =", I_pm)
print("Exato =", I_exato)
print("Erro real =", erro_real)
print("Limitante =", erro_limite)


# b)

f_expr = x*sp.log(x+1)

f = sp.lambdify(x, f_expr, 'numpy')

a = -0.5
b = 0

I_pm = ponto_medio(f, a, b)

I_exato = float(sp.integrate(f_expr, (x,a,b)))

f2 = sp.diff(f_expr, x, 2)

M2 = max(abs(float(f2.subs(x,a))),
         abs(float(f2.subs(x,b))))

erro_limite = ((b-a)**3/24)*M2

erro_real = abs(I_exato - I_pm)

print("\nb)")
print("Ponto Médio =", I_pm)
print("Exato =", I_exato)
print("Erro real =", erro_real)
print("Limitante =", erro_limite)


# c)

f_expr = sp.sin(x)**2 - 2*x*sp.sin(x) + 1

f = sp.lambdify(x, f_expr, 'numpy')

a = 0.75
b = 1.3

I_pm = ponto_medio(f, a, b)

I_exato = float(sp.integrate(f_expr, (x,a,b)))

f2 = sp.diff(f_expr, x, 2)

M2 = max(abs(float(f2.subs(x,a))),
         abs(float(f2.subs(x,b))))

erro_limite = ((b-a)**3/24)*M2

erro_real = abs(I_exato - I_pm)

print("\nc)")
print("Ponto Médio =", I_pm)
print("Exato =", I_exato)
print("Erro real =", erro_real)
print("Limitante =", erro_limite)


# d)

f_expr = 1/(x*sp.log(x))

f = sp.lambdify(x, f_expr, 'numpy')

a = np.e
b = np.e + 1

I_pm = ponto_medio(f, a, b)

I_exato = float(sp.integrate(f_expr, (x,a,b)))

f2 = sp.diff(f_expr, x, 2)

M2 = max(abs(float(f2.subs(x,a))),
         abs(float(f2.subs(x,b))))

erro_limite = ((b-a)**3/24)*M2

erro_real = abs(I_exato - I_pm)

print("\nd)")
print("Ponto Médio =", I_pm)
print("Exato =", I_exato)
print("Erro real =", erro_real)
print("Limitante =", erro_limite)
# Out:
# a)
# Ponto Médio = 0.5
# Exato = 0.4897127693021015
# Erro real = 0.010287230697898497
# Limitante = 0.009141485019691382
#
# b)
# Ponto Médio = 0.03596025905647261
# Exato = 0.05256980729002052
# Erro real = 0.016609548233547905
# Limitante = 0.03125
#
# c)
# Ponto Médio = -0.011895258503444106
# Exato = -0.020376795978874207
# Erro real = 0.0084815374754301
# Limitante = 0.012220402722178184
#
# d)
# Ponto Médio = 0.26583859242827784
# Exato = 0.2725138805025834
# Erro real = 0.006675288074305563
# Limitante = 0.014521228273960319

# %% [markdown]
# # 2.
# # (a) Se possível, efetue quatro iterações em cada função g do Exercício 1.
# #     Use p0 = 1 e pn+1 = g(pn), para n = 0, 1, 2, 3.
#
# # (b) Qual função você acredita que fornece a melhor aproximação da solução?

# %%
g1 = lambda x: (3 + x - 2*x**2)**(1/4)
g2 = lambda x: ((x + 3 - x**4)/2)**0.5
g3 = lambda x: ((x + 3)/(x**2 + 2))**0.5
g4 = lambda x: (3*x**4 + 2*x**2 + 3)/(4*x**3 + 4*x - 1)

funcoes = [g1,g2,g3,g4]
max_iter = 4

for i,g in enumerate(funcoes):
    
    print(f"\nFunção g{i+1}")
    
    p = 1
    
    for n in range(max_iter):
        p = g(p)
        print(f"p{n+1} =",p)

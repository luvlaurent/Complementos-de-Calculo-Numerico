# %% [markdown]
# # Questão 8
#
# Utilizando a fórmula de três pontos.
#
# ## a)
#
# h = 0,1
#
# f'(1,1) = (-3f(1,1)+4f(1,2)-f(1,3))/(2h)
#
# f'(1,2) = (f(1,3)-f(1,1))/(2h)
#
# f'(1,3) = (f(1,4)-f(1,2))/(2h)
#
# f'(1,4) = (3f(1,4)-4f(1,3)+f(1,2))/(2h)
#
# Resultados:
#
# | x | f'(x) |
# |---|---|
# |1,1|17,769705|
# |1,2|22,193635|
# |1,3|27,107350|
# |1,4|32,510850|
#
#
# ## b)
#
# h = 0,2
#
# Resultados:
#
# | x | f'(x) |
# |---|---|
# |8,1|3,115300|
# |8,3|3,123900|
# |8,5|3,139975|
# |8,7|3,163525|

# %%
# a)

x = [1.1, 1.2, 1.3, 1.4]
f = [9.025013, 11.02318, 13.46374, 16.44465]

h = 0.1

d11 = (-3*f[0] + 4*f[1] - f[2])/(2*h)
d12 = (f[2] - f[0])/(2*h)
d13 = (f[3] - f[1])/(2*h)
d14 = (3*f[3] - 4*f[2] + f[1])/(2*h)

print("Questão 8a")
print(d11, d12, d13, d14)

# b)

x = [8.1, 8.3, 8.5, 8.7]
f = [16.94110, 17.56492, 18.19056, 18.82091]

h = 0.2

d81 = (-3*f[0] + 4*f[1] - f[2])/(2*h)
d83 = (f[2] - f[0])/(2*h)
d85 = (f[3] - f[1])/(2*h)
d87 = (3*f[3] - 4*f[2] + f[1])/(2*h)

print("\nQuestão 8b")
print(d81, d83, d85, d87)
# Out:
# Questão 8a
# 17.769705000000016 22.193635 27.107349999999997 32.51085000000001
#
# Questão 8b
# 3.1145500000000137 3.1236500000000067 3.1399750000000015 3.163525000000007

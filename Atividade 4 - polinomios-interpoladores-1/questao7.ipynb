# %% [markdown]
# # 7. Os dados do Exercício 5 foram gerados pelas funções:
#
# # (a) f(x) = x*ln(x)
# # (b) f(x) = x^3 + 4.001x^2 + 4.002x + 1.101
# # (c) f(x) = x*cos(x) - 2x^2 + 3x - 1
# # (d) f(x) = sin(e^x - 2)
#
# # Use a fórmula do erro para encontrar um limitante
# # e compare com o erro real para n = 1 e n = 2.

# %%
import math

def f(x):
    return x*math.log(x)

def lagrange(xi, yi, x):
    soma = 0
    for i in range(len(xi)):
        termo = yi[i]
        for j in range(len(xi)):
            if i != j:
                termo *= (x-xi[j])/(xi[i]-xi[j])
        soma += termo
    return soma


# pontos da questão 5 (exemplo)
x = [8.1,8.3,8.6]
y = [16.94410,17.56492,18.50515]

xp = 8.4

aprox = lagrange(x,y,xp)
real = f(xp)

erro_real = abs(real-aprox)

# estimativa (valor genérico de derivada)
M = 10
erro_limite = (M/6)*abs((xp-x[0])*(xp-x[1])*(xp-x[2]))

print("Erro real:",erro_real)
print("Limitante:",erro_limite)
